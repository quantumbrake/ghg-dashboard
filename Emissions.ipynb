# %%
using CSV, DataFrames

# %%
co2_data_raw = DataFrame(CSV.File("data/owid-co2-data.csv"))
co2_data = dropmissing(co2_data_raw, ["iso_code", "country", "year"], disallowmissing=true)
# Out:
# 19417×38 DataFrame
#    Row │ iso_code  country      year   co2       co2_growth_prct  co2_growth_a ⋯
#        │ String    String       Int64  Float64?  Float64?         Float64?     ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │ AFG       Afghanistan   1949     0.015      missing         missing   ⋯
#      2 │ AFG       Afghanistan   1950     0.084          475.0             0.0
#      3 │ AFG       Afghanistan   1951     0.092            8.696           0.0
#      4 │ AFG       Afghanistan   1952     0.092            0.0             0.0
#      5 │ AFG       Afghanistan   1953     0.106           16.0             0.0 ⋯
#      6 │ AFG       Afghanistan   1954     0.106            0.0             0.0
#      7 │ AFG       Afghanistan   1955     0.154           44.828           0.0
#      8 │ AFG       Afghanistan   1956     0.183           19.048           0.0
# ...

# %%
energy_data_raw = DataFrame(CSV.File("data/owid-energy-data.csv"))
energy_data = dropmissing(energy_data_raw, ["iso_code", "country", "year"], disallowmissing=true)
# Out:
# 8842×117 DataFrame
#   Row │ iso_code  country      year   coal_prod_change_pct  coal_prod_change_t ⋯
#       │ String    String       Int64  Float64?              Float64?           ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ AFG       Afghanistan   1980               -35.709                -0.3 ⋯
#     2 │ AFG       Afghanistan   1981                 5.042                 0.0
#     3 │ AFG       Afghanistan   1982                16.0                   0.1
#     4 │ AFG       Afghanistan   1983                 0.0                   0.0
#     5 │ AFG       Afghanistan   1984                 2.069                 0.0 ⋯
#     6 │ AFG       Afghanistan   1985                 2.027                 0.0
#     7 │ AFG       Afghanistan   1986                 5.96                  0.0
#     8 │ AFG       Afghanistan   1987                 4.375                 0.0
# ...

# %%
names(co2_data)
# Out:
# 38-element Array{String,1}:
#  "iso_code"
#  "country"
#  "year"
#  "co2"
#  "co2_growth_prct"
#  "co2_growth_abs"
#  "consumption_co2"
#  "trade_co2"
#  "trade_co2_share"
#  "co2_per_capita"
#  "consumption_co2_per_capita"
#  "share_global_co2"
#  "cumulative_co2"
#  ⋮
#  "oil_co2_per_capita"
#  "total_ghg"
#  "ghg_per_capita"
#  "methane"
#  "methane_per_capita"
#  "nitrous_oxide"
#  "nitrous_oxide_per_capita"
#  "primary_energy_consumption"
#  "energy_per_capita"
#  "energy_per_gdp"
#  "population"
#  "gdp"

# %%
names(energy_data)
# Out:
# 117-element Array{String,1}:
#  "iso_code"
#  "country"
#  "year"
#  "coal_prod_change_pct"
#  "coal_prod_change_twh"
#  "gas_prod_change_pct"
#  "gas_prod_change_twh"
#  "oil_prod_change_pct"
#  "oil_prod_change_twh"
#  "energy_cons_change_pct"
#  "energy_cons_change_twh"
#  "biofuel_cons_change_pct"
#  "biofuel_share_energy"
#  ⋮
#  "solar_cons_change_twh"
#  "solar_consumption"
#  "solar_elec_per_capita"
#  "solar_energy_per_capita"
#  "gdp"
#  "wind_share_elec"
#  "wind_cons_change_pct"
#  "wind_share_energy"
#  "wind_cons_change_twh"
#  "wind_consumption"
#  "wind_elec_per_capita"
#  "wind_energy_per_capita"

# %%
using StatsPlots, Plots
# Out:
# ┌ Info: Precompiling StatsPlots [f3b207a7-027a-5e70-b257-86293d7955fd]
# └ @ Base loading.jl:1278

# %%
# Filter

# %%
@df co2_data plot(
    :year,
    :co2,
    group = :iso_code,
)
# Out:
# ┌ Warning: You created n=223 groups... Is that intended?
# └ @ RecipesPipeline /home/dileep/.julia/packages/RecipesPipeline/uPBKQ/src/group.jl:14
